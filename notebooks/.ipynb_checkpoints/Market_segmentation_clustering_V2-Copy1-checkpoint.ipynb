# %%
import pandas as pd
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import normalize
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
# plot full dendogram
plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
z = shc.linkage(df_final, method='ward')
cutree = shc.cut_tree(z, n_clusters= 8)
dend = shc.dendrogram(z)

# %%
last = z[-15:, 2]
last_rev = last[::-1]
idxs = np.arange(1, len(last) + 1)
plt.plot(idxs, last_rev)

acceleration = np.diff(last, 2)  # 2nd derivative of the distances
acceleration_rev = acceleration[::-1]
plt.plot(idxs[:-2] + 1, acceleration_rev)
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
# z = shc.linkage(df_final, method='ward')
# cutree = shc.cut_tree(z, n_clusters= 8)
dend = shc.dendrogram(z, truncate_mode='lastp', p = 8)

# %%
# re scale variables
for i in col_list_4:
    df_final[i] = df_final[i]*4
    
for i in col_list_5:
    df_final[i] = df_final[i]*5

# %%
df_cluster = pd.concat([df, pd.DataFrame(cutree)], axis=1)
df_cluster.columns = df.columns.tolist()+['cluster']

scaler = StandardScaler()
df_cluster_norm = scaler.fit_transform(df_cluster)
df_cluster_norm = pd.DataFrame(df_cluster_norm, columns = df_cluster.columns )

# %%
df_cluster.columns
# Out:
# Index(['Age', 'Gender', 'Population', 'Market_size', 'Market_volume_potential',
#        'Market_value_potential_overall', 'Market_value_potential_ORO',
#        'ROI_AVG', 'CLV_AVG', 'Digit_cable_share', 'Next_gen_share',
#        'RCS_RDS_share', 'Romtelecom_share', 'UPC_Romania_share', 'ORO_share',
#        'RCS_share', 'TKR_share', 'VDF_share', 'county_longitude',
#        'county_latitude', 'cluster', 'ORO_market'],
#       dtype='object')

# %%
# df_cluster.ORO_share *
df_cluster.'Population.sum()
# Out:
#   File "<ipython-input-228-76cdf35d150b>", line 2
#     df_cluster.'Population'.sum()
#                           ^
# SyntaxError: invalid syntax

# %%
df_cluster.groupby('cluster').sum()['Market_value_potential_overall']
# Out:
# cluster
# 0    4.925759e+08
# 1    3.238347e+08
# 2    4.115002e+08
# 3    2.830701e+06
# 4    7.124579e+08
# 5    4.075408e+08
# 6    2.009951e+08
# 7    1.808380e+08
# Name: Market_value_potential_overall, dtype: float64

# %%
df_cluster.columns
# Out:
# Index(['Age', 'Gender', 'Population', 'Market_size', 'Market_volume_potential',
#        'Market_value_potential_overall', 'Market_value_potential_ORO',
#        'ROI_AVG', 'CLV_AVG', 'Digit_cable_share', 'Next_gen_share',
#        'RCS_RDS_share', 'Romtelecom_share', 'UPC_Romania_share', 'ORO_share',
#        'RCS_share', 'TKR_share', 'VDF_share', 'county_longitude',
#        'county_latitude', 'cluster', 'ORO_market'],
#       dtype='object')

# %%
centroids = df_cluster.groupby('cluster').mean()
centroids = pd.concat([centroids, key], axis =1)

# %%
centroids_norm = df_cluster_norm.groupby('cluster').mean()
centroids_norm = pd.concat([centroids_norm, key], axis =1)

# %%
centroids_norm.to_csv('full_normalized_centroids.csv')
centroids.to_csv('centroids_non_norm.csv')
df_cluster.to_csv('clustered_data.csv')

# %%
# df_cluster.groupby(['cluster', 'Age']).count()

# %%
df_cluster.plot.scatter(x='CLV_AVG',
                       y='ROI_AVG',
                       c='cluster',
                       colormap='rainbow')

# %%
centroids.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64', name='cluster')

# %%
centroids.RCS_RDS_share
# Out:
# cluster
# 0    0.476100
# 1    0.581541
# 2    0.586313
# 3    0.290480
# 4    0.655190
# 5    0.589961
# 6    0.722478
# 7    0.680097
# Name: RCS_RDS_share, dtype: float64

# %%
centroids.columns
# Out:
# Index(['Age', 'Gender', 'Population', 'Market_size', 'Market_volume_potential',
#        'Market_value_potential_overall', 'Market_value_potential_ORO',
#        'ROI_AVG', 'CLV_AVG', 'Digit_cable_share', 'Next_gen_share',
#        'RCS_RDS_share', 'Romtelecom_share', 'UPC_Romania_share', 'ORO_share',
#        'RCS_share', 'TKR_share', 'VDF_share', 'county_longitude',
#        'county_latitude', 'count', 'ORO_market'],
#       dtype='object')

# %%
df_cluster['ORO_market'] = df_cluster.ORO_share * df_cluster.Market_value_potential_overall 
# centroids['ORO_market'] = centroids['ORO_market'] * centroids.count.values

df_cluster.plot.scatter(x='ORO_market',
                       y='RCS_RDS_share',
                       c='cluster',
                       colormap='rainbow')
