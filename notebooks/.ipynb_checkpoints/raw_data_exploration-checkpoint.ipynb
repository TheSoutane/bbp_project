# %% [markdown]
# This notebook offers a framework to explore the raw extracrion results

# %%
import pandas as pd

# %%
formated_data = pd.read_csv('../data/02_intermediate/cells_extracted_raw.csv')

# %%
formated_data.describe()
# Out:
#        AP_mean_stim_60  AP_mean_stim_100  AP_mean_stim_140  AP_mean_stim_180  \
# count       573.000000        653.000000        573.000000        653.000000
# mean         -1.416815         -8.840253        -23.681862        -26.747224
# std           5.229394         11.540518         13.489189         11.539142
# min         -41.992768        -52.413391        -59.231160        -57.720487
# 25%           0.000000        -17.033123        -34.769340        -34.945588
# 50%           0.000000          0.000000        -20.960063        -29.402183
# 75%           0.000000          0.000000        -15.582499        -16.885875
# max           2.285001         11.871877         14.383437         18.050624
#
#        AP_mean_stim_220  AP_stdev_stim_60  AP_stdev_stim_100  \
# count        573.000000        573.000000         653.000000
# mean         -28.192634          1.072926           5.594286
# std           10.559452          3.974752           7.971890
# ...

# %%
formated_data
# Out:
#     protocol_name  AP_mean_stim_60  AP_mean_stim_100  AP_mean_stim_140  \
# 0      APWaveform              0.0               0.0        -18.514982
# 1      APWaveform              0.0               0.0        -34.727784
# 2      APWaveform              0.0               0.0        -41.011682
# 3      APWaveform              0.0               0.0        -43.921200
# 4      APWaveform              0.0               0.0        -38.097785
# ..            ...              ...               ...               ...
# 648    APWaveform              0.0               0.0        -15.629377
# 649    APWaveform              0.0               0.0          0.000000
# 650    APWaveform              0.0               0.0        -16.336748
# 651    APWaveform              0.0               0.0          0.000000
# 652    APWaveform              0.0               0.0          0.000000
#
#      AP_mean_stim_180  AP_mean_stim_220  AP_stdev_stim_60  AP_stdev_stim_100  \
# ...

# %%
cols_60 = [x for x in formated_data.columns if ('60' in x)]

# %%
cols_60
# Out:
# ['AP_mean_stim_60',
#  'AP_stdev_stim_60',
#  'first_AP_voltage_stim_60',
#  'first_ISI_stim_60',
#  'first_fall_tau_stim_60',
#  'peak_frequency_stim_60',
#  'second_AP_voltage_stim_60',
#  'second_ISI_stim_60',
#  'second_fall_tau_stim_60',
#  'spikecount_stim_60',
#  'stim_lenght_stim_60',
#  'tau_mean_stim_60',
#  'tau_stdev_stim_60',
#  'vHold_stim_60']

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(formated_data[cols_60], figsize = (10,10))
plt.show()

# %%
formated_data.head()
# Out:
#   protocol_name  AP_mean_stim_60  AP_mean_stim_100  AP_mean_stim_140  \
# 0    APWaveform              0.0               0.0        -18.514982
# 1    APWaveform              0.0               0.0        -34.727784
# 2    APWaveform              0.0               0.0        -41.011682
# 3    APWaveform              0.0               0.0        -43.921200
# 4    APWaveform              0.0               0.0        -38.097785
#
#    AP_mean_stim_180  AP_mean_stim_220  AP_stdev_stim_60  AP_stdev_stim_100  \
# 0        -33.429730        -31.164622               0.0                0.0
# 1        -34.933940        -34.058751               0.0                0.0
# 2        -40.155257        -38.793264               0.0                0.0
# 3        -43.710375        -43.307523               0.0                0.0
# 4        -37.945658        -38.284174               0.0                0.0
#
#    AP_stdev_stim_140  AP_stdev_stim_180  ...  tau_stdev_stim_140  \
# ...

# %%
formated_data.loc[formated_data['tau_stdev_stim_140'].isna()].id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19196\956508122.py in <cell line: 1>()
# ----> 1 formated_data.loc[formated_data['tau_stdev_stim_140'].isna()].id
#
# NameError: name 'formated_data' is not defined
