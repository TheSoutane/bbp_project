# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../../data/02_intermediate/cells_extracted_raw.csv')

# %%
data.head()
# Out:
#   apwaveform_protocol_name  apwaveform_AP_mean_stim_60  \
# 0               APWaveform                         0.0
# 1               APWaveform                         0.0
# 2               APWaveform                         0.0
# 3               APWaveform                         0.0
# 4               APWaveform                         0.0
#
#    apwaveform_AP_mean_stim_100  apwaveform_AP_mean_stim_140  \
# 0                     0.000000                   -37.455832
# 1                   -37.805486                   -37.450512
# 2                     0.000000                   -35.462998
# 3                     0.000000                   -34.356585
# 4                   -20.433874                   -39.144200
#
#    apwaveform_AP_mean_stim_180  apwaveform_AP_mean_stim_220  \
# 0                   -37.526261                   -36.385932
# 1                   -38.174471                   -36.467548
# 2                   -33.668303                   -31.722114
# ...

# %%
test_list = ['apwaveform_AP_mean_stim_60', 'apwaveform_AP_mean_stim_100', 'apwaveform_AP_mean_stim_140']

# %%
data.dtypes
# Out:
# apwaveform_protocol_name        object
# apwaveform_AP_mean_stim_60     float64
# apwaveform_AP_mean_stim_100    float64
# apwaveform_AP_mean_stim_140    float64
# apwaveform_AP_mean_stim_180    float64
#                                 ...
# idrest_vHold_stim_225          float64
# idrest_vHold_stim_250          float64
# idrest_vHold_stim_275          float64
# idrest_vHold_stim_300          float64
# idrest_availability            float64
# Length: 186, dtype: object

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = data.select_dtypes(include=numerics)

# %%
data.select_dtypes(include=numerics).columns.tolist()
# Out:
# ['apwaveform_AP_mean_stim_60',
#  'apwaveform_AP_mean_stim_100',
#  'apwaveform_AP_mean_stim_140',
#  'apwaveform_AP_mean_stim_180',
#  'apwaveform_AP_mean_stim_220',
#  'apwaveform_AP_stdev_stim_60',
#  'apwaveform_AP_stdev_stim_100',
#  'apwaveform_AP_stdev_stim_140',
#  'apwaveform_AP_stdev_stim_180',
#  'apwaveform_AP_stdev_stim_220',
#  'apwaveform_first_AP_voltage_stim_60',
#  'apwaveform_first_AP_voltage_stim_100',
#  'apwaveform_first_AP_voltage_stim_140',
#  'apwaveform_first_AP_voltage_stim_180',
#  'apwaveform_first_AP_voltage_stim_220',
#  'apwaveform_first_ISI_stim_60',
#  'apwaveform_first_ISI_stim_100',
#  'apwaveform_first_ISI_stim_140',
#  'apwaveform_first_ISI_stim_180',
#  'apwaveform_first_ISI_stim_220',
#  'apwaveform_first_fall_tau_stim_60',
#  'apwaveform_first_fall_tau_stim_100',
#  'apwaveform_first_fall_tau_stim_140',
#  'apwaveform_first_fall_tau_stim_180',
#  'apwaveform_first_fall_tau_stim_220',
#  'apwaveform_peak_frequency_stim_60',
# ...

# %%
file_list = []

for col in newdf.columns:
    
    plt.figure()
    plt.hist(data[col], 30)
    plt.title(col)

    
    filename = f'data/figure_{col}.pdf'
    plt.savefig(filename)
    file_list.append(filename)
    
    plt.clf
# Out:
# C:\Users\romla\AppData\Local\Temp\ipykernel_43848\1862113566.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
from PyPDF2 import PdfFileMerger

# %%
merger = PdfFileMerger()

#Iterate over the list of the file paths
for pdf_file in file_list:
    #Append PDF files
    merger.append(pdf_file)

#Write out the merged PDF file
merger.write("merged_pages.pdf")
merger.close()
