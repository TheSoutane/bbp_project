# %%
import os
import pandas as pd

# %%
os.listdir('../data/01_raw/matData_2022-05-30/')
# Out:
# ['aCell100_1.mat',
#  'aCell100_2.mat',
#  'aCell101_1.mat',
#  'aCell101_2.mat',
#  'aCell102_1.mat',
#  'aCell103_1.mat',
#  'aCell104_1.mat',
#  'aCell105_1.mat',
#  'aCell105_2.mat',
#  'aCell106_1.mat',
#  'aCell107_1.mat',
#  'aCell107_2.mat',
#  'aCell108_1.mat',
#  'aCell108_2.mat',
#  'aCell109_1.mat',
#  'aCell109_2.mat',
#  'aCell110_1.mat',
#  'aCell110_2.mat',
#  'aCell111_1.mat',
#  'aCell111_2.mat',
#  'aCell112_1.mat',
#  'aCell112_2.mat',
#  'aCell113_1.mat',
#  'aCell113_2.mat',
#  'aCell114_1.mat',
#  'aCell115_1.mat',
#  'aCell115_2.mat',
#  'aCell116_1.mat',
#  'aCell116_2.mat',
#  'aCell117_1.mat',
#  'aCell117_2.mat',
#  'aCell118_1.mat',
#  'aCell119_1.mat',
#  'aCell11_1.mat',
#  'aCell120_1.mat',
#  'aCell120_2.mat',
#  'aCell121_1.mat',
#  'aCell121_2.mat',
#  'aCell122_1.mat',
#  'aCell122_2.mat',
#  'aCell123_1.mat',
#  'aCell123_2.mat',
#  'aCell123_3.mat',
#  'aCell124_1.mat',
#  'aCell124_2.mat',
#  'aCell124_3.mat',
#  'aCell125_1.mat',
# ...

# %%
files_to_keep_raw = pd.read_csv('../data/01_raw/CellList.csv')

# %%
files_to_keep_raw.head()
# Out:
#   CellID  Experimenter  Species  Channel  CellType                     Path  \
# 0    1_1            RP      Rat      ch4      L5PC    \140213L5ISI_1 Folder
# 1    1_2            RP      Rat      ch6      L5PC    \140213L5ISI_1 Folder
# 2    1_3            RP      Rat     ch16      L5PC    \140213L5ISI_1 Folder
# 3    1_4            RP      Rat     ch18      L5PC    \140213L5ISI_1 Folder
# 4    2_1            RP      Rat      ch8      L5PC   \140213L5ISI_10 Folder
#
#     Status
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0

# %%
files_to_keep_raw.columns
# Out:
# Index(['CellID', ' Experimenter', ' Species', ' Channel', ' CellType', ' Path',
#        ' Status'],
#       dtype='object')

# %%
files_to_keep_raw.loc[files_to_keep_raw[' Status'] ==1]['CellID'].tolist()
# Out:
# ['1_2',
#  '1_3',
#  '1_4',
#  '8_1',
#  '11_1',
#  '20_1',
#  '28_1',
#  '30_1',
#  '31_1',
#  '37_1',
#  '39_1',
#  '40_1',
#  '41_1',
#  '43_1',
#  '47_1',
#  '53_1',
#  '54_1',
#  '55_1',
#  '55_2',
#  '56_1',
#  '57_1',
#  '58_1',
#  '59_1',
#  '60_1',
#  '61_1',
#  '62_1',
#  '63_1',
#  '64_1',
#  '65_1',
#  '66_1',
#  '67_1',
#  '68_1',
#  '69_1',
#  '70_1',
#  '71_1',
#  '72_1',
#  '73_1',
#  '74_1',
#  '75_1',
#  '76_1',
#  '77_1',
#  '78_1',
#  '79_1',
#  '80_1',
#  '81_1',
#  '82_1',
#  '83_1',
#  '84_1',
#  '85_1',
#  '86_1',
#  '87_1',
#  '88_1',
#  '89_1',
#  '90_1',
#  '91_1',
#  '92_1',
#  '93_1',
#  '94_1',
#  '94_2',
#  '95_1',
#  '95_2',
#  '96_1',
#  '96_2',
#  '97_1',
#  '97_2',
#  '98_1',
#  '98_2',
#  '99_1',
#  '99_2',
#  '99_3',
#  '100_1',
#  '100_2',
#  '101_1',
#  '101_2',
#  '102_1',
#  '103_1',
#  '104_1',
#  '105_1',
#  '105_2',
#  '106_1',
#  '107_1',
#  '107_2',
#  '108_1',
#  '108_2',
#  '109_1',
#  '109_2',
#  '110_1',
#  '110_2',
#  '111_1',
# ...
