# %%
import pandas as pd
import os

# %%
data_raw = pd.read_csv('../data/02_intermediate/cells_extracted_raw.csv')
data_formated = pd.read_csv('../data/03_primary/cells_reformated.csv')

# %%
for col in data_formated.columns:
    if 'protocol' in col: print(col)
# Out:
# apwaveform_protocol_name
# dehyperpol_protocol_name
# sahp_protocol_name
# idrest_protocol_name
# has_protocols

# %%
data_raw
# Out:
#    apwaveform_protocol_name  apwaveform_stim_start  apwaveform_stim_end  \
# 0                APWaveform                  250.0               437.52
# 1                     -1500                -1500.0             -1500.00
# 2                APWaveform                  250.0               812.52
# 3                     -1500                -1500.0             -1500.00
# 4                APWaveform                  250.0               296.88
# 5                     -1500                -1500.0             -1500.00
# 6                APWaveform                  250.0               296.88
# 7                     -1500                -1500.0             -1500.00
# 8                APWaveform                  250.0               296.88
# 9                     -1500                -1500.0             -1500.00
# 10               APWaveform                  250.0               296.88
# 11                    -1500                -1500.0             -1500.00
# ...

# %%
data_raw.isna().sum()
# Out:
# apwaveform_protocol_name                     0
# apwaveform_stim_start                        0
# apwaveform_stim_end                          0
# apwaveform_min_cur_for_discharge             0
# apwaveform_first_AHP_duration_stim_60        0
#                                             ..
# apwaveform_mean_min_AHP_voltage_stim_100    12
# apwaveform_mean_tau_stim_100                12
# apwaveform_mean_time_to_AP_peak_stim_100    12
# apwaveform_mean_width_stim_100              12
# idrest_mean_adaptation_index_stim_100       16
# Length: 873, dtype: int64

# %%
data_formated.isna().sum()
# Out:
# apwaveform_protocol_name                 0
# apwaveform_stim_start                    0
# apwaveform_stim_end                      0
# apwaveform_min_cur_for_discharge         0
# apwaveform_first_AHP_duration_stim_60    0
#                                         ..
# apwaveform_mean_width_stim_100           0
# idrest_mean_adaptation_index_stim_100    0
# has_protocols                            0
# cell_group_type                          0
# cell_group_in_pc                         0
# Length: 874, dtype: int64

# %%
data_raw.isna().sum()
# Out:
# apwaveform_protocol_name                     0
# apwaveform_stim_start                        0
# apwaveform_stim_end                          0
# apwaveform_min_cur_for_discharge             0
# apwaveform_first_AHP_duration_stim_60        0
#                                             ..
# apwaveform_mean_min_AHP_voltage_stim_100    12
# apwaveform_mean_tau_stim_100                12
# apwaveform_mean_time_to_AP_peak_stim_100    12
# apwaveform_mean_width_stim_100              12
# idrest_mean_adaptation_index_stim_100       16
# Length: 873, dtype: int64

# %%
data_raw.apwaveform_protocol_name.value_counts()
# Out:
# APWaveform    9
# -1500         9
# Name: apwaveform_protocol_name, dtype: int64

# %%
data_raw.apwaveform_AP_mean_stim_220.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20052\1764299759.py in <cell line: 1>()
# ----> 1 data_raw.apwaveform_AP_mean_stim_220.value_counts()
#
# ~\anaconda3\envs\bbp_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'apwaveform_AP_mean_stim_220'

# %%
data_raw.loc[data_raw.apwaveform_AP_mean_stim_60.isna()].iloc[0][0]

# %%
data_raw.loc[data_raw.apwaveform_AP_mean_stim_60.isna()].isna()
